# %%
import pandas as pd

# %%
df = pd.read_csv('Food_Data.csv', encoding = 'latin-1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.groupby('Element')[['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
df_Protein = df[df['Element'] == 'Protein supply quantity (g/capita/day)']

# %%
df_Protein.head()
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 3           4  Algeria       2901               Grand Total           674
# 6           4  Algeria       2903          Vegetal Products           674
# 9           4  Algeria       2941           Animal Products           674
# 25          4  Algeria       2905  Cereals - Excluding Beer           674
# 41          4  Algeria       2511        Wheat and products           674
#
#                                    Element          Unit  Y2014  Y2015  Y2016  \
# 3   Protein supply quantity (g/capita/day)  g/capita/day  94.90  94.35  94.72
# 6   Protein supply quantity (g/capita/day)  g/capita/day  67.14  67.38  67.37
# 9   Protein supply quantity (g/capita/day)  g/capita/day  27.76  26.97  27.35
# 25  Protein supply quantity (g/capita/day)  g/capita/day  49.43  49.54  50.01
# 41  Protein supply quantity (g/capita/day)  g/capita/day  43.20  43.33  43.85
#
#     Y2017  Y2018
# 3   92.82  91.83
# ...

# %%
df_Protein.groupby('Area')['Y2015'].sum()
# Out:
# Area
# Algeria                        377.37
# Angola                         214.15
# Benin                          271.97
# Botswana                       278.52
# Burkina Faso                   317.99
# Cabo Verde                     278.41
# Cameroon                       291.53
# Central African Republic       173.70
# Chad                           252.28
# Congo                          227.08
# Côte d'Ivoire                  232.59
# Djibouti                       269.59
# Egypt                          394.87
# Eswatini                       237.71
# Ethiopia                       259.82
# Gabon                          345.41
# Gambia                         257.67
# Ghana                          241.71
# Guinea                         227.46
# Guinea-Bissau                  168.61
# Kenya                          251.73
# Lesotho                        254.50
# Liberia                        159.43
# Madagascar                     173.05
# ...

# %%
df.describe(include = 'all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
df.groupby('Area')[['Area', 'Y2017']].sum()
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %%
df.Area.nunique()
# Out:
# 49

# %%
my = (1,2,3)

# %%
my[1] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-ffc0d888e298> in <module>
# ----> 1 my[1] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
df['Y2014'].isnull().sum()/df.shape[0]
# Out:
# 0.026073544131401474

# %%
df.groupby('Area')[['Area', 'Y2017']].sum().sort_values('Y2017')
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
df.groupby('Item')[['Y2015', 'Y2018']].sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
Corr_1 = df['Element Code'].corr(df['Y2016'])

# %%
print(Corr_1)
# Out:
# 0.023443997584961445
